# %%
import pandas as pd
import numpy as np
from pathlib import Path

# Load the Hsu supplementary Excel
xlsx_path = '/mnt/user-uploads/41587_2026_3261_MOESM3_ESM.xlsx'
xls = pd.ExcelFile(xlsx_path)
print('Sheet names:', xls.sheet_names)

# Read all sheets
sheets = {}
for name in xls.sheet_names:
    sheets[name] = pd.read_excel(xlsx_path, sheet_name=name)
    print(f'\n=== {name} ===')
    print(f'  Shape: {sheets[name].shape}')
    print(f'  Columns: {list(sheets[name].columns)}')
